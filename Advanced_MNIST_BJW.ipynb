# %% [markdown]
# # 나만의 손글씨 만들기

# %%
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 131294 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.1-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.1-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.1-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# ...

# %%
# 이미지 파일 읽어와서 디코딩
import scipy.misc
img_array = scipy.misc.imread(image_file_name,flatten = True)

img_data = 255.0 - img_array.reshape(784)
img_data = (img_data / 255.0 * 0.99) + 0.01

# %% [markdown]
# scipy.misc.imread(image_file_name,flatten = True)
# - flatten = True : 이미지를 실수의 배열로 변화
# (만약 이미지가 색상을 가지고 있으면, 이 색상값을 그레이 스케일로 변환)
# - 255.0 - img_array.reshape(784) : 28*28 = 784의 이미지 배열을 한줄 값으로 변환 (255는 흰색, 0은 검은색을 의미 -> MNIST에 맞춰주기 위해 변환)
# - 데이터 범위 조정

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('UserNN.py','wb').write(src)
import UserNN
# Out:
#      <input type="file" id="files-072d9d44-5aa5-4457-9ec2-c810f8c7e26e" name="files[]" multiple disabled />
#      <output id="result-072d9d44-5aa5-4457-9ec2-c810f8c7e26e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving UserNN.py to UserNN.py

# %%
# png 이미지 파일에서 데이터를 불러오기 위해
import imageio
import glob
import numpy
import matplotlib.pyplot
# %matplotlib inline

# %%
our_own_dataset = []

# %%
from google.colab import drive
drive.mount("./gdrive/My Drive/Deep Learning Study/신경망 첫걸음/Practice '19.03.29/my_own_images")

# %%
for image_file_name in glob.glob("./gdrive/My Drive/Deep Learning Study/신경망 첫걸음/Practice '19.03.29/my_own_images/2828_my_own_?/*.png"):
    print ("loading ... ", image_file_name)
    # 파일 명을 사용한 인덱스 라벨링
    label = int(image_file_name[-5:-4])
    # png를 배열로 변환
    img_array = imageio.imread(image_file_name, as_gray=True)
    # 이미지 배열을 색 변환
    img_data  = 255.0 - img_array.reshape(784)
    # 데이터 스케일링(0.01에서 1)
    img_data = (img_data / 255.0 * 0.99) + 0.01
    print(numpy.min(img_data))
    print(numpy.max(img_data))
    # 데이터 appending
    record = numpy.append(label,img_data)
    print(record)
    our_own_dataset.append(record)
    pass

# %%
matplotlib.pyplot.imshow(our_own_dataset[3][1:].reshape(28,28), cmap='Greys', interpolation='None')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-c1de1738733a> in <module>()
# ----> 1 matplotlib.pyplot.imshow(our_own_dataset[3][1:].reshape(28,28), cmap='Greys', interpolation='None')
#
# IndexError: list index out of range

# %%
print(our_own_dataset)
# Out:
# []

# %%
import glob
glob.glob('my_own_images/*.*')
# Out:
# []

# %% [markdown]
# # MNIST with Rotation

# %%
ndimage.interpolation.rotate()

# %%
# 회전된 변형이미지를 생성
# 반시계 방향으로 10도 회전
input_plus10_img = scipy.ndimage.interpolation.rotate(scaled_input.reshape(28,28),
                                                     10, cval=0.01,reshape = False)
# 시계 방향으로 10도 회전
input_minus10_img = scipy.ndimage.interpolation.rotate(scaled_input.reshape(28,28),
                                                     -10, cval=0.01,reshape = False)
